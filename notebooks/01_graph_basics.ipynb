# %% [markdown]
# # Graph Basics\n\nThis notebook introduces adjacency matrices, degree matrices, Laplacians, and normalized adjacency using the code from `01_graph_basics/graph_basics.py`.

# %%
import sys\nfrom pathlib import Path\n\nPROJECT_ROOT = Path.cwd()\nif not (PROJECT_ROOT / 'README.md').exists():\n    PROJECT_ROOT = PROJECT_ROOT.parent\nsys.path.insert(0, str(PROJECT_ROOT / '01_graph_basics'))\n\nfrom graph_basics import demo_graph, degree_matrix, laplacian, normalize_adjacency

# %%
adjacency, labels = demo_graph()\nadjacency, labels

# %%
degree_matrix(adjacency)

# %%
laplacian(adjacency), normalize_adjacency(adjacency)

# %% [markdown]
# A useful mental model is that `A @ X` performs neighbor aggregation, while the normalized operator behaves more like a degree-aware averaging step. That same idea reappears in the GCN notebook.
